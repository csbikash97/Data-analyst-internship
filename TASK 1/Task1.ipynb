# %%
# importing libraries and all the library

# %%
import pandas as pd

# %%
import numpy as np

# %%
dt = pd.read_csv(r"D:\DATA ANALYST INTERNSHIP\all datasets\KaggleV2-May-2016.csv")

# %%
dt
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
dt.head(10)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5  9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6  7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7  3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8  5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9  7.812456e+13        5629123      F  2016-04-27T12:48:25Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# ...

# %%
dt.head(5)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
# checking the shape of the data set

# %%
dt.shape
# Out:
# (110527, 14)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
  # for checkig correspondig data types of columns

# %%
dt.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
# checking the null values

# %%
dt.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
for i in dt.columns:
    print(i,':',sum((dt[i])=='?'))
# Out:
# PatientId : 0
# AppointmentID : 0
# Gender : 0
# ScheduledDay : 0
# AppointmentDay : 0
# Age : 0
# Neighbourhood : 0
# Scholarship : 0
# Hipertension : 0
# Diabetes : 0
# Alcoholism : 0
# Handcap : 0
# SMS_received : 0
# No-show : 0

# %%
for i  in dt.columns:
    print(i,':','\n',dt[i].unique())
# Out:
# PatientId :
#  [2.98724998e+13 5.58997777e+14 4.26296230e+12 ... 7.26331493e+13
#  9.96997666e+14 1.55766317e+13]
# AppointmentID :
#  [5642903 5642503 5642549 ... 5630692 5630323 5629448]
# Gender :
#  ['F' 'M']
# ScheduledDay :
#  ['2016-04-29T18:38:08Z' '2016-04-29T16:08:27Z' '2016-04-29T16:19:04Z' ...
#  '2016-04-27T16:03:52Z' '2016-04-27T15:09:23Z' '2016-04-27T13:30:56Z']
# AppointmentDay :
#  ['2016-04-29T00:00:00Z' '2016-05-03T00:00:00Z' '2016-05-10T00:00:00Z'
#  '2016-05-17T00:00:00Z' '2016-05-24T00:00:00Z' '2016-05-31T00:00:00Z'
#  '2016-05-02T00:00:00Z' '2016-05-30T00:00:00Z' '2016-05-16T00:00:00Z'
#  '2016-05-04T00:00:00Z' '2016-05-19T00:00:00Z' '2016-05-12T00:00:00Z'
#  '2016-05-06T00:00:00Z' '2016-05-20T00:00:00Z' '2016-05-05T00:00:00Z'
#  '2016-05-13T00:00:00Z' '2016-05-09T00:00:00Z' '2016-05-25T00:00:00Z'
#  '2016-05-11T00:00:00Z' '2016-05-18T00:00:00Z' '2016-05-14T00:00:00Z'
#  '2016-06-02T00:00:00Z' '2016-06-03T00:00:00Z' '2016-06-06T00:00:00Z'
# ...

# %%
dt.describe(include='all')
# Out:
#            PatientId  AppointmentID  Gender          ScheduledDay  \
# count   1.105270e+05   1.105270e+05  110527                110527
# unique           NaN            NaN       2                103549
# top              NaN            NaN       F  2016-05-06T07:09:54Z
# freq             NaN            NaN   71840                    24
# mean    1.474963e+14   5.675305e+06     NaN                   NaN
# std     2.560949e+14   7.129575e+04     NaN                   NaN
# min     3.921784e+04   5.030230e+06     NaN                   NaN
# 25%     4.172614e+12   5.640286e+06     NaN                   NaN
# 50%     3.173184e+13   5.680573e+06     NaN                   NaN
# 75%     9.439172e+13   5.725524e+06     NaN                   NaN
# max     9.999816e+14   5.790484e+06     NaN                   NaN
#
#               AppointmentDay            Age   Neighbourhood    Scholarship  \
# count                 110527  110527.000000          110527  110527.000000
# ...

# %%
# Clean and extract from AppointmentDay

# %%
dt['AppointmentDay'] = pd.to_datetime(dt['AppointmentDay'], errors='coerce', utc=True)

# %%
# extract date without time

# %%
dt['Appointment_Date'] = dt['AppointmentDay'].dt.date

# %%
# extract day no

# %%
dt['Appointment_DayName'] = dt['AppointmentDay'].dt.day_name()

# %%
dt['Appointment_DayNum'] = dt['AppointmentDay'].dt.dayofweek

# %%
print(dt[['AppointmentDay', 'Appointment_Date', 'Appointment_DayName']].head())
# Out:
#              AppointmentDay Appointment_Date Appointment_DayName
# 0 2016-04-29 00:00:00+00:00       2016-04-29              Friday
# 1 2016-04-29 00:00:00+00:00       2016-04-29              Friday
# 2 2016-04-29 00:00:00+00:00       2016-04-29              Friday
# 3 2016-04-29 00:00:00+00:00       2016-04-29              Friday
# 4 2016-04-29 00:00:00+00:00       2016-04-29              Friday

# %%
# drop original

# %%
dt = dt.drop(columns=['AppointmentDay'])

# %%
dt.head(5)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  Age  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z   62
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z   56
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z   62
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z    8
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show Appointment_Date Appointment_DayName  \
# 0        0             0      No       2016-04-29              Friday
# ...

# %%
#droping the appoint day num as it not nessary

# %%
dt = dt.drop(columns=['Appointment_DayNum'])

# %%
dt.head(5)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  Age  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z   62
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z   56
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z   62
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z    8
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show Appointment_Date Appointment_DayName
# 0        0             0      No       2016-04-29              Friday
# ...

# %%
# now cleane and extract the scheduleday column

# %%
dt['ScheduledDay'] = pd.to_datetime(dt['ScheduledDay'], errors='coerce', utc=True)

# %%
dt['ScheduledDay'] = dt['ScheduledDay'].dt.date

# %%
print(dt['ScheduledDay'].dtype)
# Out:
# object

# %%
dt['ScheduledDay'] = pd.to_datetime(dt['ScheduledDay'], errors='coerce', utc=True)

# %%
# extract day and date by its name

# %%
dt['Scheduled_Date'] = dt['ScheduledDay'].dt.date
dt['Scheduled_DayName'] = dt['ScheduledDay'].dt.day_name()

# %%
print(dt[['ScheduledDay', 'Scheduled_Date', 'Scheduled_DayName']].head())
# Out:
#                ScheduledDay Scheduled_Date Scheduled_DayName
# 0 2016-04-29 00:00:00+00:00     2016-04-29            Friday
# 1 2016-04-29 00:00:00+00:00     2016-04-29            Friday
# 2 2016-04-29 00:00:00+00:00     2016-04-29            Friday
# 3 2016-04-29 00:00:00+00:00     2016-04-29            Friday
# 4 2016-04-29 00:00:00+00:00     2016-04-29            Friday

# %%
# dropping the unnessary columns

# %%
dt = dt.drop(columns=['ScheduledDay'])

# %%
dt = dt.drop(columns=['Scheduled_DayName'])

# %%
dt = dt.drop(columns=['Appointment_DayName'])

# %%
dt.head(5)
# Out:
#       PatientId  AppointmentID Gender  Age      Neighbourhood  Scholarship  \
# 0  2.987250e+13        5642903      F   62    JARDIM DA PENHA            0
# 1  5.589978e+14        5642503      M   56    JARDIM DA PENHA            0
# 2  4.262962e+12        5642549      F   62      MATA DA PRAIA            0
# 3  8.679512e+11        5642828      F    8  PONTAL DE CAMBURI            0
# 4  8.841186e+12        5642494      F   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# 1             0         0           0        0             0      No
# 2             0         0           0        0             0      No
# 3             0         0           0        0             0      No
# 4             1         1           0        0             0      No
#
#   Appointment_Date Scheduled_Date
# 0       2016-04-29     2016-04-29
# ...

# %%
# now remove scientific notation from patientid columns

# %%
print(dt['PatientId'].dtype)
# Out:
# float64

# %%
# Handle missing values and convert properly

# %%
# Convert to string safely
dt['PatientId'] = dt['PatientId'].apply(lambda x: str(int(x)) if pd.notnull(x) else None)

# %%
dt['PatientId'] = dt['PatientId'].str.zfill(2)

# %%
print(dt['PatientId'].head())
print(dt['PatientId'].dtype)
# Out:
# 0     29872499824296
# 1    558997776694438
# 2      4262962299951
# 3       867951213174
# 4      8841186448183
# Name: PatientId, dtype: object
# object

# %%
dt['PatientId'] = dt['PatientId'].str.zfill(2)

# %%
# Clean PatientId column
if 'PatientId' in dt.columns:
    dt['PatientId'] = dt['PatientId'].apply(lambda x: str(int(x)) if pd.notnull(x) else None)
    print("\n✅ PatientId column cleaned successfully!")
    print(dt['PatientId'].head())
# Out:
# ✅ PatientId column cleaned successfully!
# 0     29872499824296
# 1    558997776694438
# 2      4262962299951
# 3       867951213174
# 4      8841186448183
# Name: PatientId, dtype: object

# %%
dt.head(5)
# Out:
#          PatientId  AppointmentID Gender  Age      Neighbourhood  Scholarship  \
# 0   29872499824296        5642903      F   62    JARDIM DA PENHA            0
# 1  558997776694438        5642503      M   56    JARDIM DA PENHA            0
# 2    4262962299951        5642549      F   62      MATA DA PRAIA            0
# 3     867951213174        5642828      F    8  PONTAL DE CAMBURI            0
# 4    8841186448183        5642494      F   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# 1             0         0           0        0             0      No
# 2             0         0           0        0             0      No
# 3             0         0           0        0             0      No
# 4             1         1           0        0             0      No
#
#   Appointment_Date Scheduled_Date
# 0       2016-04-29     2016-04-29
# ...

# %%
dt.head(10)
# Out:
#          PatientId  AppointmentID Gender  Age      Neighbourhood  Scholarship  \
# 0   29872499824296        5642903      F   62    JARDIM DA PENHA            0
# 1  558997776694438        5642503      M   56    JARDIM DA PENHA            0
# 2    4262962299951        5642549      F   62      MATA DA PRAIA            0
# 3     867951213174        5642828      F    8  PONTAL DE CAMBURI            0
# 4    8841186448183        5642494      F   56    JARDIM DA PENHA            0
# 5   95985133231274        5626772      F   76          REPÚBLICA            0
# 6  733688164476661        5630279      F   23         GOIABEIRAS            0
# 7    3449833394123        5630575      F   39         GOIABEIRAS            0
# 8   56394729949972        5638447      F   21         ANDORINHAS            0
# 9   78124564369297        5629123      F   19          CONQUISTA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110527 non-null  object
#  1   AppointmentID     110527 non-null  int64
#  2   Gender            110527 non-null  object
#  3   Age               110527 non-null  int64
#  4   Neighbourhood     110527 non-null  object
#  5   Scholarship       110527 non-null  int64
#  6   Hipertension      110527 non-null  int64
#  7   Diabetes          110527 non-null  int64
#  8   Alcoholism        110527 non-null  int64
#  9   Handcap           110527 non-null  int64
#  10  SMS_received      110527 non-null  int64
#  11  No-show           110527 non-null  object
#  12  Appointment_Date  110527 non-null  object
#  13  Scheduled_Date    110527 non-null  object
# dtypes: int64(8), object(6)
# memory usage: 11.8+ MB

# %%
# Convert to numeric (handles scientific notation)
# dt['PatientId'] = pd.to_numeric(df['PatientId'], errors='coerce')

# Drop or handle missing IDs if any
# dt = dt.dropna(subset=['PatientId'])

# Convert to integer type
dt['PatientId'] = dt['PatientId'].astype('int64')

# %%
dt.dtypes
# Out:
# PatientId            int64
# AppointmentID        int64
# Gender              object
# Age                  int64
# Neighbourhood       object
# Scholarship          int64
# Hipertension         int64
# Diabetes             int64
# Alcoholism           int64
# Handcap              int64
# SMS_received         int64
# No-show             object
# Appointment_Date    object
# Scheduled_Date      object
# dtype: object

# %%
dt.head(5)
# Out:
#          PatientId  AppointmentID Gender  Age      Neighbourhood  Scholarship  \
# 0   29872499824296        5642903      F   62    JARDIM DA PENHA            0
# 1  558997776694438        5642503      M   56    JARDIM DA PENHA            0
# 2    4262962299951        5642549      F   62      MATA DA PRAIA            0
# 3     867951213174        5642828      F    8  PONTAL DE CAMBURI            0
# 4    8841186448183        5642494      F   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# 1             0         0           0        0             0      No
# 2             0         0           0        0             0      No
# 3             0         0           0        0             0      No
# 4             1         1           0        0             0      No
#
#   Appointment_Date Scheduled_Date
# 0       2016-04-29     2016-04-29
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110527 non-null  int64
#  1   AppointmentID     110527 non-null  int64
#  2   Gender            110527 non-null  object
#  3   Age               110527 non-null  int64
#  4   Neighbourhood     110527 non-null  object
#  5   Scholarship       110527 non-null  int64
#  6   Hipertension      110527 non-null  int64
#  7   Diabetes          110527 non-null  int64
#  8   Alcoholism        110527 non-null  int64
#  9   Handcap           110527 non-null  int64
#  10  SMS_received      110527 non-null  int64
#  11  No-show           110527 non-null  object
#  12  Appointment_Date  110527 non-null  object
#  13  Scheduled_Date    110527 non-null  object
# dtypes: int64(9), object(5)
# memory usage: 11.8+ MB

# %%
dt['Appointment_Date'] = dt['Appointment_Date'].astype(str)

# %%
dt['Scheduled_Date'] = dt['Scheduled_Date'].astype(str)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110527 non-null  int64
#  1   AppointmentID     110527 non-null  int64
#  2   Gender            110527 non-null  object
#  3   Age               110527 non-null  int64
#  4   Neighbourhood     110527 non-null  object
#  5   Scholarship       110527 non-null  int64
#  6   Hipertension      110527 non-null  int64
#  7   Diabetes          110527 non-null  int64
#  8   Alcoholism        110527 non-null  int64
#  9   Handcap           110527 non-null  int64
#  10  SMS_received      110527 non-null  int64
#  11  No-show           110527 non-null  object
#  12  Appointment_Date  110527 non-null  object
#  13  Scheduled_Date    110527 non-null  object
# dtypes: int64(9), object(5)
# memory usage: 11.8+ MB

# %%
dt.to_csv("Medical Appointment No Shows .csv", index=False)
